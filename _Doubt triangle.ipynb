# %%
a = int(input('enter dimesion a:'))
b = int(input('enter dimesion b:'))
c = int(input('enter dimesion c:'))
if a+b>c and b+c>a and c+a>b:
    print("accepted dimensions are of a valid triangle!!")

    if a==b and b==c:
        print("An Equilateral triangle.")
    elif a==b or b==c:
        print("An Isosceles triangle.")
    else:
        print("A Scalene triangle.")
           
else:
    print(" Invalid triangle dimensions!!")
# Out:
# enter dimesion a: 3
# enter dimesion b: 4
# enter dimesion c: 5
# accepted dimensions are of a valid triangle!!
# A Scalene triangle.

# %%
amt = 0
eu = int(input("enter  number of units consumed"))
if eu <=100:
    amt = 0
elif eu <= 200:
    amt = (eu-100)*5
else:
    amt = 500 + (eu-200)*10
print(amt)
# Out:
# enter  number of units consumed 237
# 870

# %%
amt = 0
eu = int(input("enter  number of units consumed"))
if eu <=100:
    amt = 0
if eu >100 and eu <= 200:
    amt = (eu-100)*5
if eu >200:
    amt = 500 + (eu-200)*10
print(amt)
# Out:
# enter  number of units consumed 237
# 870
