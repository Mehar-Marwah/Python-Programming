# %%
Q1)
num=int(input("Enter first number"))
num1=int(input("Enter second number"))
print(num+num1)
# Out:
# Enter first number 13
# Enter second number 16
# 29

# %%
#Q2)
#To check whether the number is odd or even
num=int(input("Enter the number"))
if num%2==0:
    print("The number is even")
else:
    print("The number is odd")
# Out:
# Enter the number 13
# The number is odd

# %%
#Q3)
list1=["Apple","Banana","Dragon fruit","Kiwi","Cherry"]
list1[2]
# Out:
# 'Dragon fruit'

# %%
list1[4]
# Out:
# 'Cherry'

# %%
#Q4)
t1=("pink","blue","green","orange")
print(len(t1))
# Out:
# 4

# %%
# Q5
num=int(input("Enter a number"))
if num>0:
    print("The number is positive")
elif num<0:
    print("The number is negative")
else:
    print("The number is zero")
# Out:
# Enter a number -13
# The number is negative

# %%
#Q6
cha=input("Enter a character")
if cha==("a","e","i","o","u"):
    print("The character is a vowel")
else:
    print("The character is a constant")
# Out:
# Enter a character A
# The character is a constant

# %%
#Functions
def check_prime():

# %%
# functions practice questions 
#Intermediate real world practice 
#Q62)
def leap_year (num):
    if num%4==0:
        print("The year is a leap year")
    else:
        print("The year is not a leap year")
leap_year(2024)
# Out:
# The year is a leap year

# %%
#Q6 Armstrong
def arm_strong(num):
