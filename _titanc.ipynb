# %%
#advanced pandas
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("tested titanic 3 december 2025.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
#not null count
#string data in general is taken as object
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.count()
# Out:
# PassengerId    418
# Survived       418
# Pclass         418
# Name           418
# Sex            418
# Age            332
# SibSp          418
# Parch          418
# Ticket         418
# Fare           417
# Cabin           91
# Embarked       418
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
#total number of rows and columns
df.shape
# Out:
# (418, 12)

# %%
df["Embarked"].value_counts()
# Out:
# Embarked
# S    270
# C    102
# Q     46
# Name: count, dtype: int64

# %%
#ascending order
(df["Embarked"].value_counts()).sort_values()
# Out:
# Embarked
# Q     46
# C    102
# S    270
# Name: count, dtype: int64

# %%
#descending order
(df["Embarked"].value_counts()).sort_values(ascending=False)
# Out:
# Embarked
# S    270
# C    102
# Q     46
# Name: count, dtype: int64

# %%
#the table will be ordered accoring to embarked
df.sort_values("Embarked")
# Out:
#      PassengerId  Survived  Pclass  \
# 208         1100         1       1
# 177         1069         0       1
# 179         1071         1       1
# 181         1073         0       1
# 184         1076         1       1
# ..           ...       ...     ...
# 228         1120         0       3
# 117         1009         1       3
# 226         1118         0       3
# 232         1124         0       3
# 248         1140         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 208                      Rosenbaum, Miss. Edith Louise  female  33.0      0
# 177                    Stengel, Mr. Charles Emil Henry    male  54.0      1
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0      0
# 181                   Compton, Mr. Alexander Taylor Jr    male  37.0      1
# 184  Douglas, Mrs. Frederick Charles (Mary Helene B...  female  27.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# sorted according to the given  columns
df.sort_values(["Embarked" , "Pclass"])
# Out:
#      PassengerId  Survived  Pclass  \
# 20           912         0       1
# 23           915         0       1
# 24           916         1       1
# 26           918         1       1
# 34           926         0       1
# ..           ...       ...     ...
# 409         1301         1       3
# 412         1304         1       3
# 413         1305         0       3
# 415         1307         0       3
# 416         1308         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 20                            Rothschild, Mr. Martin    male  55.0      1
# 23                   Williams, Mr. Richard Norris II    male  21.0      0
# 24   Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                      Ostby, Miss. Helene Ragnhild  female  22.0      0
# 34                          Mock, Mr. Philipp Edmund    male  30.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
df.drop_duplicates(subset=["Sex"])
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S

# %%
df.drop_duplicates(["Sex"])
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S

# %%
df.drop_duplicates(subset=["Sex"]).shape
# Out:
# (2, 12)

# %%
#groupby
df1=df.groupby("Embarked")
df1

# %%
#length
len(df)
# Out:
# 418

# %%
#use what u have used in groupby
df1.size()
# Out:
# Embarked
# C    102
# Q     46
# S    270
# dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 Embarked.size()
#
# NameError: name 'Embarked' is not defined

# %%
df1.first()
# Out:
#           PassengerId  Survived  Pclass  \
# Embarked
# C                 900         1       3
# Q                 892         0       3
# S                 893         1       3
#
#                                                Name     Sex   Age  SibSp  \
# Embarked
# C         Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# Q                                  Kelly, Mr. James    male  34.5      0
# S                  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
#
#           Parch  Ticket    Fare            Cabin
# Embarked
# C             0    2657  7.2292  B57 B59 B63 B66
# Q             0  330911  7.8292              C78
# S             0  363272  7.0000              B45

# %%
#Homework
#Sample suer store

# %%
df.rename(columns={"Sex":"gender"})
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  gender   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
pd.concat([df ,df1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 pd.concat([df ,df1])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# ...

# %%
#Join
df1.join(df2)

# %%
#if is null only  then true false and with sum  u will get values f nll value the true oterwise false and for sum it gets specific column for null value
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#MATPLOTLIB
#created by John D.Hunter
#It is open source

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
# we can make any kind of grah

# %%
#Simple basic code 
import matplotlib.pyplot as plt
import numpy as np # nmerical data including array

# %%
xpoints = np.array([0,6])
ypoints = np.array([0 ,250])
plt.plot(xpoints , ypoints)
plt.show()

# %%
#plotting x and y axis 
#paameter 1  is an array containg the points on the x axis 
#parameter 2 is an aray containig the points on the y axis 
import matplotlib.pyplot as plt
import numpy as np 
xpoints = ([1,8])
ypoints = ([3,10])
plt.plot(xpoints , ypoints)
plt.show()

# %%
#multiple points 
#draw a line in  a diagram  from position (1,3) to (2,8),then to (6,1) and finally to position(8,10)
import matplotlib.pyplot as plt 
import numpy as np
xpoints = np.array([1,2,6,8])
ypoints = np.array([3,8,1,10])
plt.plot(xpoints , ypoints)
plt.show()

# %%
ypoints = np.array([3,8,1,10])
plt.plot(ypoints , marker = 'o')

# %%
#matplotlib line
import matplotlib.pyplot as plt
import numpy as np 
ypoints = np.array([3 , 8 , 1 , 10])
plt.plot(ypoints , linestyle = "dotted")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 
ypoints = np.array([3 , 8 , 1 , 10])
plt.plot(ypoints , linewidth = " 20.5")
plt.show()

# %%
#matplotlib subplot 
import matplotlib.pyplot as plt
import numpy as np
#plot 1 
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
#plot 2 
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, color = 'r')
plt.show()

# %%
# SEABORN a advance version of  matplotlib 1 line command 
import  seaborn as sns
import matplotlib.pyplot as plt

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#scatterplot
sns.scatterplot(data=tips , x='total_bill' ,y=tip)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 #scatterplot
# ----> 2 sns.scatterplot(data=tips , x='total_bill' ,y=tip)
#
# NameError: name 'tip' is not defined

# %%
flights = sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
penguins = sns.load_dataset("Penguins")
penguins
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 penguins = sns.load_dataset("Penguins")
#       2 penguins
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\utils.py:573, in load_dataset(name, cache, data_home, **kws)
#     571 if not os.path.exists(cache_path):
#     572     if name not in get_dataset_names():
# --> 573         raise ValueError(f"'{name}' is not one of the example datasets.")
#     574     urlretrieve(url, cache_path)
#     575 full_path = cache_path
#
# ValueError: 'Penguins' is not one of the example datasets.

# %%
sns.scatterplot(data=tips , x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter')

# %%
flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
may_flights = flights.query("month == 'May'")
sns.lineplot(data=may_flights, x="year", y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
flights_wide = flights.pivot(index="year",columns="month",values="passengers")
flights_wide.head()
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201

# %%
#KDEplot kernel density estimate plot
flights=sns.lineplot(data=flights_wide)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #KDEplot kernel density estimate plot
# ----> 2 flights=sns.lineplot(data=flights_wide)
#
# NameError: name 'sns' is not defined
