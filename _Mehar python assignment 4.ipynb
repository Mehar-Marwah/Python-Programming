# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.head()
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.tail()
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.count()
# Out:
# sepal_length    150
# sepal_width     150
# petal_length    150
# petal_width     150
# species         150
# dtype: int64

# %%
df.shape
# Out:
# (150, 5)

# %%
(df["sepal_length"].value_counts()).sort_values()
# Out:
# sepal_length
# 7.1     1
# 7.3     1
# 7.0     1
# 4.3     1
# 4.5     1
# 5.3     1
# 7.4     1
# 7.6     1
# 7.9     1
# 4.7     2
# 6.6     2
# 6.8     3
# 7.2     3
# 5.9     3
# 4.4     3
# 7.7     4
# 6.2     4
# 5.2     4
# 4.6     4
# 6.9     4
# 4.8     5
# 6.5     5
# 6.1     6
# 5.6     6
# 6.0     6
# 5.4     6
# 4.9     6
# 6.4     7
# 5.8     7
# 5.5     7
# 5.7     8
# 6.7     8
# 6.3     9
# 5.1     9
# 5.0    10
# Name: count, dtype: int64

# %%
df.sort_values("sepal_length")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 13            4.3          3.0           1.1          0.1     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 122           7.7          2.8           6.7          2.0  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %%
df.sort_values(["sepal_length" , "species"])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 13            4.3          3.0           1.1          0.1     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %%
df.drop_duplicates()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [149 rows x 5 columns]

# %%
df.drop_duplicates(subset=["sepal_length"]).shape
# Out:
# (35, 5)

# %%
len(df)
# Out:
# 150

# %%
df1=df.groupby("sepal_length")
df1

# %%
df1.size()
df1

# %%
#if is null only  then true false and with sum  u will get values f nll value the true oterwise false and for sum it gets specific column for null value
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
#GRAPHS USING SEABORN
#Scatter plot
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris=sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(data=iris,x='sepal_length',y='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='species'>

# %%
sns.relplot(data=iris,x='petal_width',y='species',kind='scatter')

# %%
sns.displot(data=iris, x="species")

# %%
sns.lineplot(data= iris)
# Out:
# <Axes: >

# %%
sns.lineplot(data= iris["species"])
# Out:
# <Axes: ylabel='species'>

# %%
sns.displot(iris, x="petal_length", kind="kde")

# %%
sns.displot(data=iris, x="petal_length",  kde=True)

# %%
sns.histplot(data=iris, x="species")
# Out:
# <Axes: xlabel='species', ylabel='Count'>

# %%
sns.histplot(data= iris, y="species")
# Out:
# <Axes: xlabel='Count', ylabel='species'>

# %%
sns.histplot(data=iris, x="species", bins=30)
# Out:
# <Axes: xlabel='species', ylabel='Count'>

# %%
sns.kdeplot(data=iris, x="sepal_length")
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.kdeplot(data=iris, y="sepal_length")
# Out:
# <Axes: xlabel='Density', ylabel='sepal_length'>

# %%
iris = sns.load_dataset("iris")
sns.kdeplot(data=iris)
# Out:
# <Axes: ylabel='Density'>

# %%
 
sns.boxplot(x=iris["species"])
# Out:
# <Axes: xlabel='species'>

# %%
sns.boxplot(data=iris, x="petal_length", y="petal_width", hue="species")
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.violinplot(x=iris["petal_length"])
# Out:
# <Axes: xlabel='petal_length'>

# %%
sns.violinplot(data=iris, x="petal_length", y="species")
# Out:
# <Axes: xlabel='petal_length', ylabel='species'>

# %%
sns.barplot(iris, x="sepal_width", y="species")
# Out:
# <Axes: xlabel='sepal_width', ylabel='species'>

# %%
sns.countplot(iris, x="species")
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.countplot(iris, x="petal_length", hue="species")
# Out:
# <Axes: xlabel='petal_length', ylabel='count'>
