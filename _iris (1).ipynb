# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
df=pd.read_csv(r"C:/Users/dell/Desktop/python/iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sns.relplot(x="SepalLengthCm",y="PetalLengthCm" , data=df)
plt.show()

# %%
sns.scatterplot(x="PetalLengthCm" ,y="PetalLengthCm" , data=df)
plt.show()

# %%
sns.distplot(df["SepalWidthCm"])
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_18684\2327272178.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["SepalWidthCm"])

# %%
sns.histplot(df["SepalLengthCm"])
plt.show()

# %%
sns.lineplot(x="SepalLengthCm" , y="PetalLengthCm" , data=df)
plt.show()

# %%
sns.kdeplot(df["SepalLengthCm"])
plt.show()

# %%
sns.boxplot(x="Species", y="SepalLengthCm", data=df) 
plt.show()

# %%
sns.violinplot(x="Species", y="SepalLengthCm", data=df)
plt.show()

# %%
sns.barplot(x="Species", y="SepalLengthCm", data=df)
plt.show()

# %%
sns.countplot(x="Species", data=df)
plt.show()

# %%
sns.pairplot(df)
plt.show()
