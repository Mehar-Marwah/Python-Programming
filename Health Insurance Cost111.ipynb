# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Ins=pd.read_csv(r"C:/Users/dell/Desktop/python/health nsurance.csv"))

# %%
Ins
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
Ins.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
Ins.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
Ins.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
Ins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
Ins.shape
# Out:
# (1338, 7)

# %%
Ins["children"].value_counts()
# Out:
# children
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
Ins.rename(columns={"bmi":"BMI"})
# Out:
#       age     sex     BMI  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
Ins.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
Ins1=Ins.groupby("region")

# %%
len(Ins1)
# Out:
# 4

# %%
Ins1.size()
# Out:
# region
# northeast    324
# northwest    325
# southeast    364
# southwest    325
# dtype: int64

# %%
Ins1.first()
# Out:
#            age     sex     bmi  children smoker      charges
# region
# northeast   37    male  29.830         2     no   6406.41070
# northwest   33    male  22.705         0     no  21984.47061
# southeast   18    male  33.770         1     no   1725.55230
# southwest   19  female  27.900         0    yes  16884.92400

# %%
sns.barplot(x="smoker", y="age", hue="sex", data=Ins)
plt.title("Average Age by Smoking Status and Gender")
plt.show()

# %%
Ins_sorted = Ins.sort_values("age")
sns.lineplot(x="age", y="charges", data=Ins)
plt.title("Insurance Charges vs Age")
# Out:
# Text(0.5, 1.0, 'Insurance Charges vs Age')

# %%
sns.histplot(Ins["charges"], bins=30)
plt.title("Distribution of Insurance Charges")
# Out:
# Text(0.5, 1.0, 'Distribution of Insurance Charges')

# %%
sns.boxplot(x="smoker", y="charges", data=df)
plt.title("Insurance Charges by Smoking Status")
# Out:
# Text(0.5, 1.0, 'Insurance Charges by Smoking Status')

# %%
sns.barplot(x="region", y="charges", data=df)
plt.title("Average Insurance Charges by Region")
# Out:
# Text(0.5, 1.0, 'Average Insurance Charges by Region')

# %%
sns.kdeplot(df["charges"], fill=True)
plt.title("Density Plot of Insurance Charges")
# Out:
# Text(0.5, 1.0, 'Density Plot of Insurance Charges')

# %%
sns.scatterplot(x="age", y="charges", data=df)
plt.title("Age vs Insurance Charges")
# Out:
# Text(0.5, 1.0, 'Age vs Insurance Charges')

# %%
sns.relplot(x="age", y="charges",hue="sex",col="region",data=Ins)
plt.title("Age vs Insurance Charges")
# Out:
# Text(0.5, 1.0, 'Age vs Insurance Charges')

# %%
sns.barplot(x="children", y="charges", hue="sex", data=Ins)
plt.title("Insurance Charges by Number of Children and Gender")
plt.show()

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.pairplot(Ins)
